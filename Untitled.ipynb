# %%
import matplotlib.pyplot as plt
oscar_movies=[
"The dark Knight",
"The hurt locker",
"The king's Speech",
"The Artist",
"Argo"    
]
o_revenue=[1005,170,427,133,232]
years=[2008,2009,2010,2011,2012]
plt.plot(years,o_revenue)
plt.title("Oscar movies year and revenue")
plt.xlabel("year")
plt.ylabel("revenue ($M)")
plt.show()

# %%
import matplotlib.pyplot as plt
oscar_movies=[
"The dark Knight",
"The hurt locker",
"The king's Speech",
"The Artist",
"Argo"    
]
o_revenue=[1005,170,427,133,232]

non_oscar=["Slumdog Millionaire","Avatar","Inception","Hugo","Lincoln"]
nonoscar_revenue=[378,2788,829,185,275]

years=[2008,2009,2010,2011,2012]
plt.plot(years,o_revenue, label="Oscar movies",color="red")
plt.plot(years,nonoscar_revenue, label="non_oscar movies")
plt.title("Oscar movies vs non_oscar movies")
plt.xlabel("year")
plt.ylabel("revenue ($M)")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
oscar_movies=["The dark Knight","The hurt locker","The king's Speech","The Artist","Argo" ]
o_revenue=[1005,170,427,133,232]

non_oscar=["Slumdog Millionaire","Avatar","Inception","Hugo","Lincoln"]
nonoscar_revenue=[378,2788,829,185,275]

years=[2008,2009,2010,2011,2012]
x = np.arange(len(years))
width=0.4
plt.bar(x-width/2,o_revenue,width, label="oscar movies")
plt.bar(x+width/2,nonoscar_revenue,width,label="non_oscar movies")
plt.title("Oscar vs non_oscar movies")
plt.xlabel("year")
plt.ylabel("revenue  ($M)")
(x,years)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
oscar_movies=[
"The dark Knight",
"The hurt locker",
"The king's Speech",
"The Artist",
"Argo"    
]
o_revenue=[1005,170,427,133,232]

non_oscar=["Slumdog Millionaire","Avatar","Inception","Hugo","Lincoln"]
nonoscar_revenue=[378,2788,829,185,275]

years=[2008,2009,2010,2011,2012]
plt.scatter(years,o_revenue, label="Oscar movies",color="red")
plt.scatter(years,nonoscar_revenue, label="non_oscar movies")
plt.title("Oscar movies vs non_oscar movies")
plt.xlabel("year")
plt.ylabel("revenue ($M)")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
oscar_movies=["The dark Knight","The hurt locker","The king's Speech","The Artist","Argo" ]
o_revenue=[1005,170,427,133,232]
explode=[0,0,0,0.2,0]
plt.style.use("default")
plt.pie(o_revenue,labels=oscar_movies,autopct="%1.1f%%",explode=explode)
plt.show()
